# %% [markdown]
# # Join Statements - Lab
#
# ## Introduction
#
# In this lab, you'll practice your knowledge of join statements, using various types of joins and various methods for specifying the links between them.
#
# ## Objectives
#
# You will be able to:
# - Write queries that make use of various types of Joins
# - Join tables using foreign keys

# %% [markdown]
# ## CRM Schema
#
# In almost all cases, rather then just working with a single table you will typically need data from multiple tables.
# Doing this requires the use of **joins ** using shared columns from the two tables.
#
# In this lab, you'll use the same Customer Relationship Management (CRM) database that you saw from the previous lesson.
# <img src='images/Database-Schema.png' width="600">

# %% [markdown]
# ## Connecting to the Database
# Import the necessary packages and connect to the database **data.sqlite**.

# %%
#Your code here
import pandas as pd
import sqlite3

# %%
conn= sqlite3.connect('data.sqlite')
c= conn.cursor()

# %%
# Out:
#   employeeNumber   lastName firstName extension  \
# 0           1002     Murphy     Diane     x5800
# 1           1056  Patterson      Mary     x4611
# 2           1076   Firrelli      Jeff     x9273
# 3           1088  Patterson   William     x4871
# 4           1102     Bondur    Gerard     x5408
#
#                              email officeCode reportsTo              jobTitle
# 0     dmurphy@classicmodelcars.com          1                       President
# 1   mpatterso@classicmodelcars.com          1      1002              VP Sales
# 2   jfirrelli@classicmodelcars.com          1      1002          VP Marketing
# 3  wpatterson@classicmodelcars.com          6      1056  Sales Manager (APAC)
# 4     gbondur@classicmodelcars.com          4      1056   Sale Manager (EMEA)

# %% [markdown]
# ## Display the names of all the employees in Boston.
# Hint: join the employees and customers tables.

# %%
#Your code here
c.execute('''select lastName, firstName, city
            from employees e
            join customers c
            on e.employeeNumber = c.SalesRepEmployeeNumber
            where city = 'Boston'
            ;''')
df= pd.DataFrame(c.fetchall())
df.columns= [i[0] for i in c.description]
df
# Out:
#     lastName firstName    city
# 0  Patterson     Steve  Boston
# 1   Firrelli     Julie  Boston

# %% [markdown]
# ## Do any offices have no employees?
# Hint: Combine the employees and offices tables and use a group by.

# %%
#Your code here
c.execute('''select * from employees
            join offices
            using (officeCode)
            ;''')
df= pd.DataFrame(c.fetchall())
df.columns= [i[0] for i in c.description]
len(df)
# Out:
# 23

# %% [markdown]
# ## Write 3 Questions of your own and answer them

# %%
# Answers will vary

# %%
# Your code here
c.execute('''select from;''')
df= pd.DataFrame(c.fetchall())
df.columns= [i[0] for i in c.description]
df

# %%
# Your code here
c.execute('''select from;''')
df= pd.DataFrame(c.fetchall())
df.columns= [i[0] for i in c.description]
df

# %%
# Your code here
c.execute('''select from;''')
df= pd.DataFrame(c.fetchall())
df.columns= [i[0] for i in c.description]
df

# %% [markdown]
# ## Level Up: Display the names of each product each employee has sold

# %%
# Your code here
c.execute('''select firstName, lastName, productName 
                from employees e
                join customers c
                on e.employeeNumber = c.SalesRepEmployeeNumber
                join orders
                using(customerNumber)
                join orderDetails
                using(orderNumber)
                join products
                using(productCode)
                ''')
df= pd.DataFrame(c.fetchall())
df.columns= [i[0] for i in c.description]
df = df.groupby(df['lastName'])
df.head()
# Out:
#      firstName   lastName                                  productName
# 0       Leslie   Jennings                               1958 Setra Bus
# 1       Leslie   Jennings                       1940 Ford Pickup Truck
# 2       Leslie   Jennings                      1939 Cadillac Limousine
# 3       Leslie   Jennings  1996 Peterbilt 379 Stake Bed with Outrigger
# 4       Leslie   Jennings                            1968 Ford Mustang
# 331     Leslie   Thompson                     1917 Grand Touring Sedan
# 332     Leslie   Thompson                           1911 Ford Town Car
# 333     Leslie   Thompson                    1932 Model A Ford J-Coupe
# 334     Leslie   Thompson          1932 Alfa Romeo 8C2300 Spider Sport
# 335     Leslie   Thompson                        1957 Ford Thunderbird
# 445      Julie   Firrelli                     1952 Alpine Renault 1300
# 446      Julie   Firrelli                       1940 Ford Pickup Truck
# 447      Julie   Firrelli                  1913 Ford Model T Speedster
# 448      Julie   Firrelli                           1934 Ford V8 Coupe
# 449      Julie   Firrelli          18th Century Vintage Horse Carriage
# 569      Steve  Patterson                            2001 Ferrari Enzo
# 570      Steve  Patterson                           1969 Corvair Monza
